# %% [markdown]
# Learn:
#
# pandas - groupby facility to slice, dice, summarize datasets
# NumPy - numerical python
# IPython - exploratory computing
# Jupyter - exploratory computing
# matplotlib - create informative visuals
# Analyze and manipulate regular and irregular time series data
#
#
# Load, clean, transform, merge, reshape data

# %% [markdown]
# # 1. Preliminaries

# %% [markdown]
# Structured Data
# -tabular or spread-sheet like
# -multidimentional arrays (matrices)
# -multiple tables of data interelated by keys (SQL)
# -evenly or unevenly spaced time series

# %% [markdown]
# Unstructured Data
# -news articles processed into work frequency tables (perform sentiment analysis)

# %% [markdown]
# Webframeworks (scipting programming language)
# -Rails (Ruby)
# -Django (Python)
#
# Python
# -Data Science
# -Machine Learning
# -General Software Development
#
# linear algebra, optimization, integration, fast Fourier transforms, and other such algorithms
# -C
# -C++
# -FORTRAN
#
# Python vs. Java/C++
# -Python has faster programmer time
# -Java/C++ has faster CPU time (better for performance)
#
# Essential Python Libraries
# -NumPy
# -pandas = panel + data
#     -primary objects (DataFrame, tabular column-oriented data structure)
#     -Series, one-dementional labeled array object
# -matplotlib
#     -plots and 2D visualizations
# -IPython and Jupyter
#     -interactive Python interpreter
#     -(execute-explore) workflow instead of (edit-compile-run)
#     -easy access to shell and file system
#     -exploration, trial and error, and iteration
#     -IPython web notebook turned into Jupyter Notebook (supports 40+ languages)
#         -accelerate the writing, testing, and debugging of Python code
# -SciPy
#     scipy.integrate
#     scipy.linalg
#     scipy.optimize
#     scipy.signal
#     scipy.sparse
#     scipy.special
#     scipy.stats
# -scikit-learn
#     general purpose ML toolkit
#     prediction-focused
#     • Classification: SVM, nearest neighbors, random forest, logistic regression, etc.
#     • Regression: Lasso, ridge regression, etc.
#     • Clustering: k-means, spectral clustering, etc.
#     • Dimensionality reduction: PCA, feature selection, matrix factorization, etc.
#     • Model selection: Grid search, cross-validation, metrics
#     • Preprocessing: Feature extraction, normalization
# -statsmodels
#     classical stats and econometrics
#     focused on statistical inference
#     • Regression models: Linear regression, generalized linear models, robust linear
#     models, linear mixed effects models, etc.
#     • Analysis of variance (ANOVA)
#     • Time series analysis: AR, ARMA, ARIMA, VAR, and other models
#     • Nonparametric methods: Kernel density estimation, kernel regression
#     • Visualization of statistical model results

# %% [markdown]
# Downloads
#
# Anaconda
#     - https://www.anaconda.com/products/individual
#     Windows:
#         Check Python and Anaconda version or to exit shell in the command prompt (Ctrl + Z)
#         ![image.png](attachment:image.png)
#     Mac:
#         ![image.png](attachment:image.png)

# %% [markdown]
# Installing Python packages:
#     $ conda install package-name
#     or
#     $ pip install package-name
#
# Upgrade a specific package or all packages:
#     $ conda update package-name
#     $ conda update --all
#     or
#     $ pip install --upgrade package-name

# %% [markdown]
# Integrated Development Environments (IDEs) and Text Editors
#     text editor for building software
#     • PyDev (free), an IDE built on the Eclipse platform
#     • PyCharm from JetBrains (subscription-based for commercial users, free for open
#     source developers)
#     • Python Tools for Visual Studio (for Windows users)
#     • Spyder (free), an IDE currently shipped with Anaconda
#     • Komodo IDE (commercial)

# %% [markdown]
# # 2. Python Language Basics, IPython, Jupyter Notebooks

# %% [markdown]
# # 3. Built-in Data Structures, Functions and Files

# %% [markdown]
# # 4. NumPy Basics: Arrays and Vectorized Computation

# %% [markdown]
# # 5. Getting Started with Pandas

# %% [markdown]
# # 6. Data Loading, Storage, and File Formats

# %% [markdown]
# # 7. Data Cleaning and Preperation

# %% [markdown]
# # 8. Data Wrangling: Join, Combine, and Reshape

# %% [markdown]
# # 9. Plotting and Visualization

# %% [markdown]
# # 10. Data Aggregation and Group Operations

# %% [markdown]
# # 11. Time Series

# %% [markdown]
# # 12. Advanced Pandas

# %% [markdown]
# # 13. Introduction to Modeling Libraries in Python

# %% [markdown]
# # 14. Data Anaysis Examples

# %% [markdown]
# # A. Advanced NumPy

# %% [markdown]
# # B. More on the IPython System

# %% [markdown]
# Python for Data Analysis by Wes
# McKinney (O’Reilly). Copyright 2017 Wes McKinney, 978-1-491-95766-0
#
# GITHUB: https://github.com/wesm/pydata-book
